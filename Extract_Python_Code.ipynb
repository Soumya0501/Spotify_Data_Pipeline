# %%
# !pip install spotipy
# Out:
# ...
#    ---------------------------------------- 0.0/261.3 kB ? eta -:--:--
#    --------- ------------------------------ 61.4/261.3 kB 3.2 MB/s eta 0:00:01
#    ------------------------------------ --- 235.5/261.3 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 261.3/261.3 kB 2.7 MB/s eta 0:00:00
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id = "2ab614e660ae4a429de9945eae490d67", client_secret = "c4d9ae635fd5422ca36a6013fa811ec3")

# %%
spotify = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist = spotify.user_playlists('spotify')

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF"

# %%
playlist_URI = playlist_link.split("/")[-1]
playlist_URI
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
data = spotify.playlist_tracks(playlist_URI)

# %%
len(data['items'])
# Out:
# 50

# %%
data['items'][0]['track']
# Out:
# {'added_at': '2024-10-11T12:30:50Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '10FLjwfpbxLmW8c25Xyc2N'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Die With A Smile'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-08-16'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id, 'name':album_name, 'release_date':album_release_date,
                    'total_tracks':album_total_tracks, 'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '10FLjwfpbxLmW8c25Xyc2N',
#   'name': 'Die With A Smile',
#   'release_date': '2024-08-16',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/10FLjwfpbxLmW8c25Xyc2N'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'name': 'HIT ME HARD AND SOFT',
#   'release_date': '2024-05-17',
#   'total_tracks': 10,
#   'url': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'name': 'MUSE',
#   'release_date': '2024-07-19',
#   'total_tracks': 7,
#   'url': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
#  {'album_id': '3iPSVi54hsacKKl1xIR2eH',
#   'name': "Short n' Sweet",
#   'release_date': '2024-08-23',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/3iPSVi54hsacKKl1xIR2eH'},
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'},
#   'href': 'https://api.spotify.com/v1/artists/0du5cEVh5yTK9QJze8zA0C',
#   'id': '0du5cEVh5yTK9QJze8zA0C',
#   'name': 'Bruno Mars',
#   'type': 'artist',
#   'uri': 'spotify:artist:0du5cEVh5yTK9QJze8zA0C'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id': artist['id'], 'artist_name': artist['name'],
                 'external_url': artist['external_urls']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1HY2Jd0NmPuamShAr6KMms',
#   'artist_name': 'Lady Gaga',
#   'external_url': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'}},
#  {'artist_id': '0du5cEVh5yTK9QJze8zA0C',
#   'artist_name': 'Bruno Mars',
#   'external_url': {'spotify': 'https://open.spotify.com/artist/0du5cEVh5yTK9QJze8zA0C'}},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'}},
#  {'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'external_url': {'spotify': 'https://open.spotify.com/artist/1oSPZhvZMIrWW5I41kPkkY'}},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': {'spotify': 'https://open.spotify.com/artist/74KM79TiuVKeVCqs8QtB0B'}},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id': song_id, 'song_name': song_name, 'duration_ms': song_duration,
                   'url': song_url, 'popularity': song_popularity, 'song_added': song_added,
                   'album_id': album_id, 'artist_id': artist_id}
    song_list.append(song_element)

# %%
import pandas as pd
album_df = pd.DataFrame.from_dict(album_list)
album_df.head()
# Out:
#                  album_id                  name release_date  total_tracks  \
# 0  10FLjwfpbxLmW8c25Xyc2N      Die With A Smile   2024-08-16             1
# 1  7aJuG4TFXa2hmE4z1yxc3n  HIT ME HARD AND SOFT   2024-05-17            10
# 2  15XcLhiVMlSOipUddTNDnr                  MUSE   2024-07-19             7
# 3  3iPSVi54hsacKKl1xIR2eH        Short n' Sweet   2024-08-23            12
# 4  3iPSVi54hsacKKl1xIR2eH        Short n' Sweet   2024-08-23            12
#
#                                                  url
# 0  https://open.spotify.com/album/10FLjwfpbxLmW8c...
# 1  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 3  https://open.spotify.com/album/3iPSVi54hsacKKl...
# 4  https://open.spotify.com/album/3iPSVi54hsacKKl...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset = 'album_id')

# %%
artist_df = pd.DataFrame.from_dict(artist_list)
artist_df = artist_df.drop_duplicates(subset = ['artist_id'])

# %%
artist_df.head()
# Out:
#                 artist_id        artist_name  \
# 0  1HY2Jd0NmPuamShAr6KMms          Lady Gaga
# 1  0du5cEVh5yTK9QJze8zA0C         Bruno Mars
# 2  6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish
# 3  1oSPZhvZMIrWW5I41kPkkY              Jimin
# 4  74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
#
#                                         external_url
# 0  {'spotify': 'https://open.spotify.com/artist/1...
# 1  {'spotify': 'https://open.spotify.com/artist/0...
# 2  {'spotify': 'https://open.spotify.com/artist/6...
# 3  {'spotify': 'https://open.spotify.com/artist/1...
# 4  {'spotify': 'https://open.spotify.com/artist/7...

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, 0 to 66
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     52 non-null     object
#  1   artist_name   52 non-null     object
#  2   external_url  52 non-null     object
# dtypes: object(3)
# memory usage: 1.6+ KB

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id           song_name  duration_ms  \
# 0  2plbrEY59IikOBgBGLjaoe    Die With A Smile       251667
# 1  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER       210373
# 2  7tI8dRuH2Yc6RuoTjxo4dU                 Who       170887
# 3  5G2f63n7IPVPPjfNIGih7Q               Taste       157279
# 4  2HRqTpkrJO5ggZyyK6NPWz            Espresso       175459
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/2plbrEY59IikOBg...         100
# 1  https://open.spotify.com/track/6dOtVTDdiauQNBQ...          98
# 2  https://open.spotify.com/track/7tI8dRuH2Yc6Ruo...          93
# 3  https://open.spotify.com/track/5G2f63n7IPVPPjf...          95
# 4  https://open.spotify.com/track/2HRqTpkrJO5ggZy...          87
#
#              song_added                album_id               artist_id
# 0  2024-10-11T12:30:50Z  10FLjwfpbxLmW8c25Xyc2N  1HY2Jd0NmPuamShAr6KMms
# 1  2024-10-11T12:30:50Z  7aJuG4TFXa2hmE4z1yxc3n  6qqNVTkY8uBg9cP3Jd7DAH
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     object
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ KB

# %% [markdown]
# #### we can observe that the album_df has release_date datatype as object which needs to be converted to datatime datatype, same for song_added in song_df data

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      43 non-null     object
#  1   name          43 non-null     object
#  2   release_date  43 non-null     datetime64[ns]
#  3   total_tracks  43 non-null     int64
#  4   url           43 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.0+ KB

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB
